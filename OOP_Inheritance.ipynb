# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzeem131/blood_donation_app/blob/master/OOP_Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Inheritance in Python
# Inheritance is a powerful feature in object oriented programming.
#
# * It refers to defining a new class with little or no modification to an existing class.
# * The new class is called derived (or child) class and the one from which it inherits is called the base (or parent) class.
# * Derived class inherits features from the base class where new features can be added to it. This results in re-usability of code.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Inheritance is the capability of a class to pass some of its properties or methods to it’s derived class(child class). With inheritance, we build a relationship between classes based on how they are derived.
#
# **class BaseClass:**
#   * Body of base class
#
# class DerivedClass(BaseClass):
#   * Body of derived class

# %%
class Fruit:
  pass

class Grapes(Fruit):
  pass

issubclass(Grapes, Fruit)

# %% [markdown]
# ### Advantages of Inheritance:
# * It provides reusability of a code.
# * It is transitive in nature, which means that if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Single Inheritance in Python
# In single inheritance, a single class inherits from a class. This is the simplest form of inheritance.single inheritance in python

# %%
class Parent:
    def show(self):
        print("Parent method")
class Child(Parent):
    def display(self):
        print("Child method")
c = Child()
c.display()
c.show()
# Out:
# Child method
# Parent method

# %% [markdown]
# **2. Multilevel Inheritance in Python**
# * No limit on the number of levels that  can be inherited.
# *  Achieve multilevel inheritance by inheriting one class from another which then is inherited from another class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class A:
    def methodA(self):
        print("A class")
class B(A):
    def methodB(self):
        print("B class")
class C(B):
    def methodC(self):
        print("C class")
c = C()
c.methodA()
c.methodB()
c.methodC()
# Out:
# A class
# B class
# C class

# %% [markdown]
# **3. Multiple Inheritance in Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class A:
    def methodA(self):
        print("A class")
class B:
    def methodB(self):
        print("B class")
class C:
    def methodC(self):
        print("C class")
class D(A, B, C):
    def methodD(self):
        print("D class")
d = D()
d.methodA()
d.methodB()
d.methodC()
d.methodD()
# Out:
# A class
# B class
# C class
# D class

# %%
# Program 1:
class Person(object):
       
    # Constructor
    def __init__(self, name):
        self.name = name
   
    # To get name
    def getName(self):
        return self.name
   
    # To check if this person is a student
    def isStudent(self):
        return False
   
# Inherited or Subclass (Note Person in bracket)
class Student(Person):
   
    # Check and return true
    def isStudent(self):
        return True
   
# Driver code
st = Person("OOP Course")  # An Object of Person
print(st.getName(), st.isStudent())
   
st = Student("CSE COurse") # An Object of Student
print(st.getName(), st.isStudent())
# Out:
# OOP Course False
# CSE COurse True

# %% [markdown]
# **4. Hierarchical Inheritance in Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class A:
    def methodA(self):
        print("A class")
class B(A):
    def methodB(self):
        print("B class")
class C(A):
    def methodC(self):
        print("C class")
b = B()
c = C()
b.methodA()
c.methodA()
# Out:
# A class
# A class

# %% [markdown]
# **5. Hybrid Inheritance in Python**
#
# * The term Hybrid describes that it is a mixture of more than one type. Hybrid inheritance is a combination of different types of inheritance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class A:
    def methodA(self):
        print("A class")
class B(A):
    def methodB(self):
        print("B class")
class C(A):
    def methodC(self):
        print("C class")
class D(B,C):
    def methodD(self):
        print("D class")
d = D()
d.methodA()
# Out:
# A class

# %% [markdown]
# **Python Inheritance – super() function**
# * When dealing with inheritance, super() is a very handy function. super() is a proxy object which is used to refer to the parent object.
# * We can call super() method to access the properties or methods of the parent class.

# %%
class A:
    x=100
    def methodA(self):
        print("A class")
class B(A):
    def methodB(self):
        super().methodA()
        print("B class")
        print(super().x)
b = B()
b.methodB()
# Out:
# A class
# B class
# 100

# %%
# Problem 2:   
# parent class
class Person( object ):    
        # __init__ is known as the constructor         
        def __init__(self, name, idnumber):   
                self.name = name
                self.idnumber = idnumber
        def display(self):
                print(self.name)
                print(self.idnumber)
# child class
class Student( Person ):           
        def __init__(self, name, idnumber, deptid,state):
                self.deptid = deptid
                self.state = state
  
                # invoking the __init__ of the parent class 
                Person.__init__(self, name, idnumber) 
  
# creation of an object variable or an instance
st = Student('Ram',"2020BCS001", "ECE100", "KA")    
  
# calling a function of the class Person using its instance
st.display()
# Out:
# Ram
# 2020BCS001

# %%
# Program 3: Python program to demonstrate error if 
#  __init__() of the parent is not invoked
  
class A(object):
      def __init__(self,n):
              self.name = n
class B(A):
      def __init__(self,roll,n):
              self.roll = roll

              A.__init__(self,n)      #  if this is removed, it gives an error              
  
course = B("OOP Course",200)
print (course.name)
# Out:
# 200

# %%
# Program 4:
class Polygon:
    def __init__(self, no_of_sides):
        self.n = no_of_sides
        self.sides = [0 for i in range(no_of_sides)]

    def inputSides(self):
        self.sides = [float(input("Enter side "+str(i+1)+" : ")) for i in range(self.n)]

    def dispSides(self):
        for i in range(self.n):
            print("Side",i+1,"is",self.sides[i])

# %%
class Triangle(Polygon):
    def __init__(self):
        Polygon.__init__(self,3)

    def findArea(self):
        a, b, c = self.sides
        # calculate the semi-perimeter
        s = (a + b + c) / 2
        area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
        print('The area of the triangle is %0.2f' %area)

t = Triangle()
t.inputSides()
t.dispSides()
t.findArea()
# Out:
# Enter side 1 : 8
# Enter side 2 : 7
# Enter side 3 : 9
# Side 1 is 8.0
# Side 2 is 7.0
# Side 3 is 9.0
# The area of the triangle is 26.83
